# %%
# !pip3 install google-generativeai

# %%
import google.generativeai as genai
import os

# Configurar la clave de API
os.environ["GOOGLE_API_KEY"] = "AIzaSyAPHcWEW2tPqmjsD5FBdKl0Bz1_ZZgXBO4"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
model = genai.GenerativeModel('models/gemini-1.5-flash')
response = model.generate_content("Dame una explicacion simple y completa del uso de la libreria numpy en python")
print(response.text)
# Out:
# ## NumPy: Tu mejor amigo para trabajar con números en Python
#
# Imagina que tienes un montón de números con los que necesitas trabajar: calcular promedios, encontrar el valor máximo, ordenar, etc. Python por sí solo puede hacerlo, pero NumPy te da superpoderes para hacerlo de forma rápida y eficiente.
#
# **¿Qué es NumPy?**
#
# Es una biblioteca de Python que te permite crear y manipular **arrays multidimensionales**, es decir, matrices de números. Puedes pensar en ellas como hojas de cálculo súper poderosas.
#
# **¿Por qué es tan genial?**
#
# 1. **Rendimiento:** NumPy está optimizado para trabajar con números. Sus operaciones son mucho más rápidas que usar listas de Python estándar.
# 2. **Facilidad de uso:** Tiene funciones y métodos específicos para operar con arrays, lo que simplifica tareas complejas.
# 3. **Aplicaciones:**  Es la base de muchas bibliotecas científicas de Python, como SciPy, pandas, Matplotlib, etc.
#
# **¿Cómo se utiliza?**
#
# ...

# %%
model = genai.GenerativeModel('gemini-1.5-pro-latest')
response = model.generate_content("Dame una explicacion simple y completa del uso de la libreria numpy en python")
print(response.text)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y = 3 * x * x - 6 * x + 2
yr = y + np.random.normal(0, 10, 100)
plt.scatter(x, yr)
plt.plot(x, y, c='r')

# %%
import pandas as pd

# Crear un DataFrame
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Marta'],
    'Edad': [23, 45, 34, None],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla']
}
df = pd.DataFrame(data)

# Ver las primeras filas
print("Datos resumen")
print(df.head())

# Rellenar valores nulos
df['Edad'] = df['Edad'].fillna(df['Edad'].mean())

# Filtrar filas
df_filtered = df[df['Edad'] > 30]
print("Datos filtrados")
print(df_filtered)

# Añadir una nueva columna
df['País'] = 'España'

print("Datos original")
print(df)

# Ordenar por Edad

df_sorted = df.sort_values(by='Edad')
print("Datos ordenados")
print(df_sorted)

# Guardar el DataFrame en un archivo CSV
df.to_csv('datos_modificados.csv', index=False)
# Out:
# Datos resumen
#    Nombre  Edad     Ciudad
# 0     Ana  23.0     Madrid
# 1    Luis  45.0  Barcelona
# 2  Carlos  34.0   Valencia
# 3   Marta   NaN    Sevilla
# Datos filtrados
#    Nombre  Edad     Ciudad
# 1    Luis  45.0  Barcelona
# 2  Carlos  34.0   Valencia
# 3   Marta  34.0    Sevilla
# Datos original
#    Nombre  Edad     Ciudad    País
# 0     Ana  23.0     Madrid  España
# 1    Luis  45.0  Barcelona  España
# 2  Carlos  34.0   Valencia  España
# 3   Marta  34.0    Sevilla  España
# Datos ordenados
#    Nombre  Edad     Ciudad    País
# 0     Ana  23.0     Madrid  España
# 2  Carlos  34.0   Valencia  España
# 3   Marta  34.0    Sevilla  España
# 1    Luis  45.0  Barcelona  España

# %%
x = np.linspace(-10, 10, 100)
y = 3 * x * x * x * x - 6 * x * x + - 6 * x + 2
yr = y + np.random.normal(0, 10, 100)

fd = pd.DataFrame({'x': x, 'y': y, 'yr': yr})
fd.to_csv('datos_generados.csv', index=False)
plt.scatter(x, yr)

# %%
ds = pd.read_csv('datos_generados.csv')
plt.plot(ds['x'], ds['y'], c='r')
plt.scatter(ds['x'], ds['yr'])

print(np.sum(ds['yr']))
a=np.polynomial.polynomial.polyfit(ds['x'], ds['yr'], 5)
plt.plot(ds['x'], np.polynomial.polynomial.polyval(ds['x'], a), c='g')
# Out:
# 604070.0996501704

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Datos de entrada y salida (sin normalizar)
x = ds.x.values
y = ds.yr.values


# Crear el modelo
model = Sequential()
model.add(Dense(units=16, activation='relu', input_shape=(1,)))
model.add(Dense(units=16, activation='relu'))  # Capa oculta adicional
model.add(Dense(units=1))  # Capa de salida

# Compilar el modelo
model.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
model.fit(x, y, epochs=500, verbose=1)

# Hacer predicciones
y_pred = model.predict(x)

# Visualizar resultados
plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Datos Reales', color='blue')
plt.plot(x, y_pred, label='Curva Ajustada', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 20090.4824
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19855.3262
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21393.4688
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20217.0312
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21610.0273
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18856.5469
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20168.9824
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19381.5410
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19461.8594
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18688.5781
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22303.6348
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19034.3242
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18637.2617
# Epoch 14/500
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Datos de entrada y salida (sin normalizar)
x = ds.x.values
y = ds.yr.values

# Crear el modelo
model = Sequential()
model.add(Dense(units=1, input_shape=(1,), use_bias=False, kernel_initializer='zeros'))
model.add(Dense(units=1, use_bias=False, kernel_initializer='zeros'))
model.add(Dense(units=1, use_bias=False, kernel_initializer='zeros'))
model.add(Dense(units=1, use_bias=False, kernel_initializer='zeros'))

# Compilar el modelo
model.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
model.fit(x, y, epochs=500, verbose=1)

# Hacer predicciones
y_pred = model.predict(x)

# Visualizar resultados
plt.figure(figsize=(10, 6))
plt.scatter(x, y, label='Datos Reales', color='blue')
plt.plot(x, y_pred, label='Curva Ajustada', color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 19757.1387
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22321.7129
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19846.0762
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21528.5586
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20584.5156
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19929.8477
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21526.0742
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20947.9297
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22883.7402
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21892.2793
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20212.0488
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20940.4551
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21932.3184
# Epoch 14/500
# ...
